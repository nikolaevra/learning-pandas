# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('GlobalLandTemperaturesByMajorCity 2.csv')

# %%
df
# Out:
#                 dt  AverageTemperature  AverageTemperatureUncertainty  \
# 0       1849-01-01              26.704                          1.435
# 1       1849-02-01              27.434                          1.362
# 2       1849-03-01              28.101                          1.612
# 3       1849-04-01              26.140                          1.387
# 4       1849-05-01              25.427                          1.200
# 5       1849-06-01              24.844                          1.402
# 6       1849-07-01              24.058                          1.254
# 7       1849-08-01              23.576                          1.265
# 8       1849-09-01              23.662                          1.226
# 9       1849-10-01              25.263                          1.175
# 10      1849-11-01              26.332                          1.507
# 11      1849-12-01              25.450                          1.838
# ...

# %%
for name, group in df.groupby('Country'):
    print name
    print group
# Out:
# Afghanistan
#                 dt  AverageTemperature  AverageTemperatureUncertainty   City  \
# 105635  1833-01-01               2.290                          2.487  Kabul
# 105636  1833-02-01               3.319                          2.325  Kabul
# 105637  1833-03-01               7.444                          2.733  Kabul
# 105638  1833-04-01              13.576                          2.266  Kabul
# 105639  1833-05-01              19.321                          2.362  Kabul
# 105640  1833-06-01              24.406                          1.972  Kabul
# 105641  1833-07-01              25.447                          1.620  Kabul
# 105642  1833-08-01              23.827                          1.778  Kabul
# 105643  1833-09-01              19.593                          1.749  Kabul
# 105644  1833-10-01              13.870                          1.762  Kabul
# 105645  1833-11-01              10.029                          2.016  Kabul
# ...

# %%
for (k1 ,k2), group in df.groupby(['City', 'Country']):
    print k1
    print k2
    print group
    break
# Out:
# Abidjan
# Côte D'Ivoire
#               dt  AverageTemperature  AverageTemperatureUncertainty     City  \
# 0     1849-01-01              26.704                          1.435  Abidjan
# 1     1849-02-01              27.434                          1.362  Abidjan
# 2     1849-03-01              28.101                          1.612  Abidjan
# 3     1849-04-01              26.140                          1.387  Abidjan
# 4     1849-05-01              25.427                          1.200  Abidjan
# 5     1849-06-01              24.844                          1.402  Abidjan
# 6     1849-07-01              24.058                          1.254  Abidjan
# 7     1849-08-01              23.576                          1.265  Abidjan
# 8     1849-09-01              23.662                          1.226  Abidjan
# 9     1849-10-01              25.263                          1.175  Abidjan
# 10    1849-11-01              26.332                          1.507  Abidjan
# ...

# %%
pieces = dict(list(df.groupby('City')))

# %%
pieces.keys()
# Out:
# ['Kinshasa',
#  'Kiev',
#  'Madras',
#  'Paris',
#  'Fortaleza',
#  'Bangkok',
#  'Santiago',
#  'Addis Abeba',
#  'Delhi',
#  'Baghdad',
#  'Taipei',
#  'Ahmadabad',
#  'Pune',
#  'Nagpur',
#  'Rome',
#  'Tangshan',
#  'Surat',
#  'Ho Chi Minh City',
#  'Mogadishu',
#  'Harbin',
#  'Casablanca',
#  'Alexandria',
#  'Kanpur',
#  'Cairo',
#  'Shenyang',
#  'Abidjan',
#  'London',
#  'Bombay',
#  'Harare',
#  'Sydney',
#  'Dakar',
#  'Seoul',
#  'Singapore',
#  'Moscow',
#  'Guangzhou',
#  'Berlin',
#  'Los Angeles',
#  'Bangalore',
#  'Karachi',
#  'Ibadan',
#  'Cape Town',
#  'Taiyuan',
#  'Kano',
#  'Lakhnau',
#  'Madrid',
#  'Xian',
#  'Rio De Janeiro',
#  'Dar Es Salaam',
#  'Istanbul',
#  'Mashhad',
#  'Aleppo',
#  'Manila',
#  'Lahore',
#  'Luanda',
#  'Durban',
#  'Jaipur',
#  'Faisalabad',
#  'Gizeh',
#  'Rangoon',
#  'New Delhi',
#  'Nagoya',
#  'Wuhan',
#  'Calcutta',
#  'Nairobi',
#  'Montreal',
#  'Umm Durman',
#  'Mexico',
#  'Saint Petersburg',
#  'New York',
#  'Lima',
# ...

# %%
df.dtypes
# Out:
# dt                                object
# AverageTemperature               float64
# AverageTemperatureUncertainty    float64
# City                              object
# Country                           object
# Latitude                          object
# Longitude                         object
# dtype: object
